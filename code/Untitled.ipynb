# %%
import thinkdsp
import thinkplot
import numpy as np
from scipy.io import wavfile

from __future__ import print_function, division

# %matplotlib inline

from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets
from IPython.display import display

# %%
segment = thinkdsp.read_wave('audio_1.wav')
segment.framerate = 11025
segment.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
dct = segment.make_dct()
dct.plot()
thinkplot.config(xlabel='Frecuencia(Hz)', ylabel='DCT')

# %%
wave2 = dct.make_wave()
wave2.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fs = 44100
signal = np.int16(wave2)
wavfile.write('audio_1_1.wav', fs, signal)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-a2fbe44c285b> in <module>()
#       1 fs = 44100
# ----> 2 signal = np.int16(wave2)
#       3 wavfile.write('audio_1_1.wav', fs, signal)
#
# AttributeError: Wave instance has no attribute '__trunc__'
